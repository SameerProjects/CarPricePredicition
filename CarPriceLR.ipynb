# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cars_clean.csv', index_col=0)
pd.set_option('display.max_columns', None)
df
# Out:
#        manufacturer               model  year   mileage  \
# 2             Acura     ILX Hybrid 1.5L  2013   53422.0
# 5             Acura     ILX Hybrid 1.5L  2013   62042.0
# 13            Acura               NSX T  2001   28734.0
# 14            Acura            NSX Base  2017   15904.0
# 15            Acura               NSX T  1998   82602.0
# ...             ...                 ...   ...       ...
# 762081        Volvo  S60 T6 Inscription  2020   12337.0
# 762084        Volvo  S60 T6 Inscription  2019   33319.0
# 762085        Volvo              S60 T5  2020   26781.0
# 762086        Volvo     S60 B5 Momentum  2022   22877.0
# 762089        Volvo     S60 T5 Platinum  2013  132000.0
#
#                                        engine       transmission  \
# 2                 1.5L I4 8V MPFI SOHC Hybrid      Automatic CVT
# 5                 1.5L I4 8V MPFI SOHC Hybrid      Automatic CVT
# 13                      3.2L V6 24V MPFI DOHC     6-Speed Manual
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241257 entries, 0 to 241256
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           241257 non-null  int64
#  1   manufacturer         241257 non-null  object
#  2   model                241257 non-null  object
#  3   year                 241257 non-null  int64
#  4   mileage              241257 non-null  float64
#  5   engine               241257 non-null  object
#  6   transmission         241257 non-null  object
#  7   drivetrain           241257 non-null  object
#  8   fuel_type            241257 non-null  object
#  9   mpg                  241257 non-null  object
#  10  exterior_color       241257 non-null  object
#  11  interior_color       241257 non-null  object
#  12  accidents_or_damage  241257 non-null  float64
#  13  one_owner            241257 non-null  float64
# ...

# %%
print(df.describe())
# Out:
#           Unnamed: 0           year        mileage  accidents_or_damage  \
# count  241257.000000  241257.000000  241257.000000        241257.000000
# mean   386229.360595    2018.428949   52146.280183             0.236486
# std    219695.363029       3.231882   37371.256936             0.424925
# min         2.000000    1983.000000       0.000000             0.000000
# 25%    194841.000000    2017.000000   24782.000000             0.000000
# 50%    395936.000000    2019.000000   43395.000000             0.000000
# 75%    572232.000000    2021.000000   70785.000000             0.000000
# max    762089.000000    2023.000000  938032.000000             1.000000
#
#            one_owner  personal_use_only  seller_rating  driver_rating  \
# count  241257.000000      241257.000000  241257.000000  241257.000000
# mean        0.589152           0.692195       4.195884       4.656621
# std         0.491989           0.461586       0.772056       0.239190
# ...

# %%
df.manufacturer.unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hyundai', 'INFINITI',
#        'Jaguar', 'Jeep', 'Kia', 'Land Rover', 'Lexus', 'Lincoln', 'Mazda',
#        'Mercedes-Benz', 'Mitsubishi', 'Nissan', 'Porsche', 'RAM',
#        'Subaru', 'Toyota', 'Volkswagen', 'Volvo'], dtype=object)

# %%
def display_nunique(col):
    print(f'{col} uniques: {df[col].nunique()}')
    

display_nunique('engine')
display_nunique('transmission')
display_nunique('drivetrain')
display_nunique('fuel_type')
display_nunique('mpg')
display_nunique('exterior_color')
display_nunique('interior_color')
display_nunique('seller_name')
# Out:
# engine uniques: 1818
# transmission uniques: 255
# drivetrain uniques: 8
# fuel_type uniques: 10
# mpg uniques: 521
# exterior_color uniques: 4172
# interior_color uniques: 2115
# seller_name uniques: 8451

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap="Blues")
# Out:
# <AxesSubplot:>
